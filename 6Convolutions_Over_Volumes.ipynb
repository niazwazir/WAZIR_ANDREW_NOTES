# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5c7eb07-05cc-40fb-af07-05f9ab1cd9df" name="files[]" multiple disabled />
#      <output id="result-c5c7eb07-05cc-40fb-af07-05f9ab1cd9df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ABC.png to ABC.png

# %%
# !ls
# Out:
# 1C4W1L06.png  2C4W1L06.png  ABC.png  AC.png  sample_data

# %%
from IPython.display import Image
Image('1C4W1L06.png')

# %%
from IPython.display import Image
Image('2C4W1L06.png')

# %%
from IPython.display import Image
Image('AC.png')

# %%
from IPython.display import Image
Image('ABC.png')

# %%
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Activation, Input
from keras import optimizers
from keras.models import load_model
import numpy as np
import scipy.misc
import scipy.ndimage
import cv2
import math
import glob
import matplotlib.pyplot as plt

# %%
img_shape = (6,6,3)
input_img = Input(shape=(img_shape))
C1 = Conv2D(2,(3,3),padding='VALID',name='CONV1')(input_img)#2 is number of filters



model = Model(input_img, C1)
opt = optimizers.Adam(lr=0.0003)
model.compile(optimizer=opt,loss='mean_squared_error')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 6, 6, 3)           0
# _________________________________________________________________
# CONV1 (Conv2D)               (None, 4, 4, 2)           56
# =================================================================
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# _________________________________________________________________
